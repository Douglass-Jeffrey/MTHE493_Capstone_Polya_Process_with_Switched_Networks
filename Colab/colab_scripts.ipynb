# %%
# !ls
# Out:
# sample_data

# %%
# !pwd
# Out:
# /content

# %%
# !git clone https://github.com/Douglass-Jeffrey/MTHE493_Capstone_Polya_Process_with_Switched_Networks -b optimization
# Out:
# Cloning into 'MTHE493_Capstone_Polya_Process_with_Switched_Networks'...
# remote: Enumerating objects: 456, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 456 (delta 23), reused 42 (delta 16), pack-reused 403 (from 1)
# Receiving objects: 100% (456/456), 46.12 MiB | 17.68 MiB/s, done.
# Resolving deltas: 100% (229/229), done.

# %%
# !pip install virtualenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 94.5 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 34.7 MB/s eta 0:00:00
# ...

# %%
# !virtualenv .venv
# Out:
# created virtual environment CPython3.12.12.final.0-64-x86_64 in 348ms
#   creator CPython3Posix(dest=/content/.venv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.cache/virtualenv)
#     added seed packages: pip==26.0.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source .venv/bin/activate

# %%
# !python MTHE493_Capstone_Polya_Process_with_Switched_Networks/src/capstone_optimized/experiments/test_node_growth_intervention_polya.py
# Out:
# using CuPy (devices=1)
# cupy_fallback: cp module = cupy CUPY_AVAILABLE= True
# Starting growth phase: 256 batches of size 8...
# Starting growth phase: 256 batches of size 256...
# Starting growth phase: 256 batches of size 8192...
# Resizing Stubs: 1000000 -> 1500000
# Resizing Stubs: 1500000 -> 2250000
# Resizing Stubs: 2250000 -> 3375000
# Resizing Stubs: 3375000 -> 5062500
# Resizing Stubs: 5062500 -> 7593750
# Resizing Stubs: 7593750 -> 11390625
# Starting growth phase: 128 batches of size 65536...
# Resizing Stubs: 11390625 -> 17085937
# Resizing Stubs: 17085937 -> 25628905
# Resizing Stubs: 25628905 -> 38443357
# Resizing Stubs: 38443357 -> 57665035
# All growth phases complete. Total growth time: 5.296s
# Building CSR adjacency matrix...
# Building CSR on CPU then moving to GPU
# CSR build time: 2.946s
# Running Polya process...
# Polya step 0/720 time=2.166s
# Polya step 100/720 time=0.060s
# Building CSR on CPU then moving to GPU
# Polya step 200/720 time=0.060s
# ...
